# %%
import pandas as pd
dataset=pd.read_csv("prePlacement.csv")
dataset.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# # Covariance

# %%
dataset.cov()
# Out:
#                   sl_no         ssc_p         hsc_p      degree_p  \
# sl_no       3870.000000    -52.641355    -58.106028    -40.413645
# ssc_p        -52.641355    117.228377     60.348373     42.897137
# hsc_p        -58.106028     60.348373    118.755706     34.819820
# degree_p     -40.413645     42.897137     34.819820     54.151103
# etest_p       52.556168     37.659225     35.461678     21.929469
# mba_p          8.102336     24.535952     22.555846     17.272020
# salary    361617.668689  28777.386468  66977.716032 -11739.948520
#
#                 etest_p         mba_p        salary
# sl_no         52.556168      8.102336  3.616177e+05
# ssc_p         37.659225     24.535952  2.877739e+04
# hsc_p         35.461678     22.555846  6.697772e+04
# degree_p      21.929469     17.272020 -1.173995e+04
# etest_p      176.251018     16.886973  2.287876e+05
# mba_p         16.886973     34.028376  9.624979e+04
# salary    228787.619507  96249.789024  8.734295e+09

# %% [markdown]
# # Correlation

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %%
dataset.corrwith(dataset["mba_p"])
# Out:
# sl_no       0.022327
# ssc_p       0.388478
# hsc_p       0.354823
# degree_p    0.402364
# etest_p     0.218055
# mba_p       1.000000
# salary      0.175013
# dtype: float64

# %% [markdown]
# # Preprocessing

# %%
dataset=dataset.drop(columns='sl_no')
dataset=dataset.dropna()

# %% [markdown]
# # Visulaize the pair

# %%
import seaborn as sns
sns.pairplot(dataset,hue="ssc_b")

import matplotlib.pyplot as plt
plt.savefig('pairplot_ssc_b.png')

# %% [markdown]
# # Calling user defined function Descriptive file

# %%
pip install Descriptive file
# Out:
# Collecting DescriptiveNote: you may need to restart the kernel to use updated packages.
#
#   Using cached descriptive-0.0.0.tar.gz (3.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting file
#   Downloading file-0.3.0.tar.gz (15 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: PyYAML>=3 in c:\anaconda3\envs\aiml\lib\site-packages (from Descriptive) (6.0.1)
# Requirement already satisfied: boto3<1.10,>=1.7.0 in c:\anaconda3\envs\aiml\lib\site-packages (from Descriptive) (1.9.253)
# Requirement already satisfied: cffi>=1.0.0 in c:\anaconda3\envs\aiml\lib\site-packages (from file) (1.15.1)
# Requirement already satisfied: botocore<1.13.0,>=1.12.253 in c:\anaconda3\envs\aiml\lib\site-packages (from boto3<1.10,>=1.7.0->Descriptive) (1.12.253)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\anaconda3\envs\aiml\lib\site-packages (from boto3<1.10,>=1.7.0->Descriptive) (0.10.0)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in c:\anaconda3\envs\aiml\lib\site-packages (from boto3<1.10,>=1.7.0->Descriptive) (0.2.1)
# Requirement already satisfied: pycparser in c:\anaconda3\envs\aiml\lib\site-packages (from cffi>=1.0.0->file) (2.21)
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\anaconda3\envs\aiml\lib\site-packages (from botocore<1.13.0,>=1.12.253->boto3<1.10,>=1.7.0->Descriptive) (0.15.2)
# Requirement already satisfied: urllib3<1.26,>=1.20 in c:\anaconda3\envs\aiml\lib\site-packages (from botocore<1.13.0,>=1.12.253->boto3<1.10,>=1.7.0->Descriptive) (1.25.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\anaconda3\envs\aiml\lib\site-packages (from botocore<1.13.0,>=1.12.253->boto3<1.10,>=1.7.0->Descriptive) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\envs\aiml\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.13.0,>=1.12.253->boto3<1.10,>=1.7.0->Descriptive) (1.16.0)
# Building wheels for collected packages: Descriptive, file
#   Building wheel for Descriptive (setup.py): started
#   Building wheel for Descriptive (setup.py): finished with status 'error'
#   Running setup.py clean for Descriptive
#   Building wheel for file (setup.py): started
#   Building wheel for file (setup.py): finished with status 'error'
#   Running setup.py clean for file
# Failed to build Descriptive file
# Installing collected packages: file, Descriptive
#   Running setup.py install for file: started
#   Running setup.py install for file: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [36 lines of output]
#   C:\anaconda3\envs\aiml\lib\site-packages\setuptools\installer.py:30: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     SetuptoolsDeprecationWarning,
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib
#   creating build\lib\miniscule
#   copying src\miniscule\aws.py -> build\lib\miniscule
#   copying src\miniscule\base.py -> build\lib\miniscule
#   copying src\miniscule\__init__.py -> build\lib\miniscule
#   running egg_info
#   writing descriptive.egg-info\PKG-INFO
#   C:\anaconda3\envs\aiml\lib\site-packages\setuptools\dist.py:159: UserWarning: newlines not allowed and will break in the future
#     warnings.warn("newlines not allowed and will break in the future")
#   writing dependency_links to descriptive.egg-info\dependency_links.txt
#   writing requirements to descriptive.egg-info\requires.txt
#   writing top-level names to descriptive.egg-info\top_level.txt
#   reading manifest file 'descriptive.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   writing manifest file 'descriptive.egg-info\SOURCES.txt'
#   C:\anaconda3\envs\aiml\lib\site-packages\setuptools\command\install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     setuptools.SetuptoolsDeprecationWarning,
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\miniscule
#   copying build\lib\miniscule\aws.py -> build\bdist.win-amd64\wheel\.\miniscule
#   copying build\lib\miniscule\base.py -> build\bdist.win-amd64\wheel\.\miniscule
#   copying build\lib\miniscule\__init__.py -> build\bdist.win-amd64\wheel\.\miniscule
#   running install_data
#   creating build\bdist.win-amd64\wheel\descriptive-0.0.0.data
#   creating build\bdist.win-amd64\wheel\descriptive-0.0.0.data\data
#   error: can't copy 'VERSION': doesn't exist or not a regular file
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for Descriptive
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [28 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-37
#   creating build\lib.win-amd64-cpython-37\file
#   copying src\file\_libmagic_build.py -> build\lib.win-amd64-cpython-37\file
#   copying src\file\__init__.py -> build\lib.win-amd64-cpython-37\file
#   running egg_info
#   writing src\file.egg-info\PKG-INFO
#   writing dependency_links to src\file.egg-info\dependency_links.txt
#   writing requirements to src\file.egg-info\requires.txt
#   writing top-level names to src\file.egg-info\top_level.txt
#   reading manifest file 'src\file.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files matching '*.py[cod]' found anywhere in distribution
#   warning: no previously-included files matching '__pycache__' found anywhere in distribution
#   warning: no previously-included files matching '*.so' found anywhere in distribution
#   warning: no previously-included files matching '*.dylib' found anywhere in distribution
#   adding license file 'LICENSE'
#   adding license file 'AUTHORS.rst'
#   writing manifest file 'src\file.egg-info\SOURCES.txt'
#   running build_ext
#   generating cffi module 'build\\temp.win-amd64-cpython-37\\Release\\file._libmagic.c'
#   creating build\temp.win-amd64-cpython-37
#   creating build\temp.win-amd64-cpython-37\Release
#   building 'file._libmagic' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for file
#   error: subprocess-exited-with-error
#
#   Running setup.py install for file did not run successfully.
#   exit code: 1
#
#   [30 lines of output]
#   running install
#   C:\anaconda3\envs\aiml\lib\site-packages\setuptools\command\install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     setuptools.SetuptoolsDeprecationWarning,
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-37
#   creating build\lib.win-amd64-cpython-37\file
#   copying src\file\_libmagic_build.py -> build\lib.win-amd64-cpython-37\file
#   copying src\file\__init__.py -> build\lib.win-amd64-cpython-37\file
#   running egg_info
#   writing src\file.egg-info\PKG-INFO
#   writing dependency_links to src\file.egg-info\dependency_links.txt
#   writing requirements to src\file.egg-info\requires.txt
#   writing top-level names to src\file.egg-info\top_level.txt
#   reading manifest file 'src\file.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files matching '*.py[cod]' found anywhere in distribution
#   warning: no previously-included files matching '__pycache__' found anywhere in distribution
#   warning: no previously-included files matching '*.so' found anywhere in distribution
#   warning: no previously-included files matching '*.dylib' found anywhere in distribution
#   adding license file 'LICENSE'
#   adding license file 'AUTHORS.rst'
#   writing manifest file 'src\file.egg-info\SOURCES.txt'
#   running build_ext
#   generating cffi module 'build\\temp.win-amd64-cpython-37\\Release\\file._libmagic.c'
#   creating build\temp.win-amd64-cpython-37
#   creating build\temp.win-amd64-cpython-37\Release
#   building 'file._libmagic' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# file
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
from Descriptive import Descriptive

obj=Descriptive()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10004\1196931087.py in <module>
# ----> 1 from Descriptive import Descriptive
#       2
#       3 obj=Descriptive()
#
# ModuleNotFoundError: No module named 'Descriptive'

# %% [markdown]
# # Sregrating quantitative Data and qualtative

# %%
quan,qual=obj.segreQuanQual(dataset)

# %%
quan_data=dataset[quan]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(quan_data)

# %%
quan_data=dataset[['etest_p','salary',]]

# %% [markdown]
# # Univarite Analysis

# %% [markdown]
# ## Probability Density Function(PDF)

# %%
# Density Polt

import seaborn as sns
x=dataset['ssc_p']
ax = sns.distplot(dataset['ssc_p'],kde=True)

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset['ssc_p'],60,60)

# %% [markdown]
# # cumulative Density function

# %%
import matplotlib.pyplot as plt
x=dataset['ssc_p']
plt.hist(x,cumulative=True, density=True,bins=100)

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(dataset['ssc_p'])
ecdf(65)

# %% [markdown]
# # Types of Test

# %% [markdown]
# # Z- Score: Normal distribution to Standard Normal Distribution

# %%
# Normal Distribution
import seaborn as sns
sns.distplot(dataset['ssc_p'],kde=True)

# %%
# Coverted to standard Normal Distribution
import seaborn as sns
mean=dataset['ssc_p'].mean()
std=dataset['ssc_p'].std()

values=[i for i in dataset['ssc_p']]

z_score=[((j-mean)/std) for j in values]

sns.distplot(z_score,kde=True)

sum(z_score)/len(z_score)
#z_score.std()

# %%
dataset

# %%
dataset[dataset["gender"]=="M"]["salary"]

# %% [markdown]
# # T-Test

# %% [markdown]
# #### Independant Sample
# Diferrent Group(Male, Female) but same contion(salary)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['salary']
female = dataset[dataset['gender']=='F']['salary']
#print(male)
ttest_ind(male, female)

# %% [markdown]
# #### Dependant Sample
# Same Group(Male) but Different Condition(ssc_p,hsc_p)

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['ssc_p']
male1 = dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male, male1)

# %% [markdown]
# ### for one sample mean
#
# should same for different sample
#
# scipy.stats.ttest_1samp(a, popmean, axis=0, nan_policy='propagate')

# %% [markdown]
# # ANAVO : Analysis of Variance

# %% [markdown]
# ## One-Way Classification

# %%
import scipy.stats as stats

stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

#perform two-way ANOVA
model = ols('degree_p ~ C(ssc_p) + C(hsc_p) + C(ssc_p):C(hsc_p)', data=dataset).fit()
sm.stats.anova_lm(model, typ=2)
